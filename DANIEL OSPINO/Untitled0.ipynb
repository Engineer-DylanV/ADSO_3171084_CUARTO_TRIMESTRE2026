# %%
class Libro: #clase
  def __init__(self, titulo, precio): #constructor
     self.__titulo = titulo #atributos
     self.__precio = precio

  def get_precio(self):
      return self.__precio

  def set_precio(self, nuevo_precio):
    if isinstance(nuevo_precio, (int, float)) and nuevo_precio > 0:
      self.__precio = nuevo_precio
    else:
      print("el precio debe ser un numero positivo.")

  def mostrar_info(self):
    print(f"\nTitulo: {self.__titulo}")
    print(f"precio: {self.__precio:,.2f}")
    print("----------------------")
    print(f"Titulo: {self.__titulo}, precio: {self.__precio}\n")

def main():
    libro1 = Libro("python profesional", 120000) # crear objeto utilizando la plantilla libro
    libro2 = Libro("java profesional", 150000)

    # Mostrar informacion inicial
    print("Informacion inicial del libro")
    libro1.mostrar_info()
    libro2.mostrar_info()

    # Mostrar precio actual
    print("precio actual (Libro1): ", libro1.get_precio())

    # intento de actualizacion no valida
    print("\nIntentando actualizar con un precio no valido...")
    libro1.set_precio(-10)

    # Actualizacion correctamente
    print("\nActualizando precio correctamente...")
    libro1.set_precio(135000)

    print("Nuevo precio (Libro1):", libro1.get_precio())
    print("\nprograma finalizado. ")

if __name__ == "__main__":
    main()
# Out:
# Informacion inicial del libro
#
# Titulo: python profesional
# precio: 120,000.00
# ----------------------
# Titulo: python profesional, precio: 120000
#
#
# Titulo: java profesional
# precio: 150,000.00
# ----------------------
# Titulo: java profesional, precio: 150000
#
# precio actual (Libro1):  120000
#
# Intentando actualizar con un precio no valido...
# el precio debe ser un numero positivo.
#
# Actualizando precio correctamente...
# Nuevo precio (Libro1): 135000
#
# programa finalizado.
